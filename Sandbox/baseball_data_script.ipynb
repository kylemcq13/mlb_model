# %% [markdown]
# # Baseball Data Script
#
# - The purpose of this notebook is to experiment with baseball data scraping scripts. pyBaseball will be used to fetch the data, which will ultimately land in my personal sql server.
# - Every MLB team is needed
# - Statcast data along with advanced stats should be scraped
# - Tables should be named by stat category and date scraped.
# - The goal is to have time sliced MLB data.
# - Frequency of data scraping yet to be determined.

# %%
from datetime import date
from datetime import datetime
from configparser import ConfigParser
import pandas as pd
import pybaseball
from pybaseball import statcast
import psycopg2
from sqlalchemy import create_engine
from datetime import date

today = date.today()
st = "statcast_{}".format(today)
st
# Out:
# 'statcast_2021-10-26'

# %%
# use config parser for security purposes

parser = ConfigParser()
parser.read('nb.ini')
conn_string = parser.get('my_db', 'conn_string')
engine = create_engine(conn_string)

# %%
current_year = datetime.now().year
current_year
# Out:
# 2021

# %% [markdown]
# ### Statcast Data
# - This data can be overwritten when writing to the sql database. Current table in SQL has 2019, 2020 and up to date 2021 statcast data.

# %%
# scrape statcast data

pybaseball.cache.enable()
statcast_2019 = statcast('2019-03-31', '2019-11-30')
statcast_2019['year'] = 2019
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/214 [00:00<?, ?it/s]
# Skipping offseason dates
# 100%|██████████| 214/214 [00:24<00:00,  8.81it/s]

# %%
statcast_2019.to_csv('F:/datasets/statcast_2019.csv')

# %%
statcast_2019 = pd.read_csv('F:/datasets/statcast_2019.csv')

# %%
statcast_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732071 entries, 0 to 732070
# Data columns (total 94 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   Unnamed: 0                       732071 non-null  int64
#  1   pitch_type                       726981 non-null  object
#  2   game_date                        732071 non-null  object
#  3   release_speed                    725452 non-null  float64
#  4   release_pos_x                    725431 non-null  float64
#  5   release_pos_z                    725431 non-null  float64
#  6   player_name                      732071 non-null  object
#  7   batter                           732071 non-null  int64
#  8   pitcher                          732071 non-null  int64
#  9   events                           185858 non-null  object
#  10  description                      732071 non-null  object
#  11  spin_dir                         0 non-null       float64
#  12  spin_rate_deprecated             0 non-null       float64
#  13  break_angle_deprecated           0 non-null       float64
#  14  break_length_deprecated          0 non-null       float64
#  15  zone                             725431 non-null  float64
#  16  des                              732071 non-null  object
#  17  game_type                        732071 non-null  object
#  18  stand                            732071 non-null  object
#  19  p_throws                         732071 non-null  object
#  20  home_team                        732071 non-null  object
#  21  away_team                        732071 non-null  object
#  22  type                             732071 non-null  object
#  23  hit_location                     161495 non-null  float64
#  24  bb_type                          125595 non-null  object
#  25  balls                            732071 non-null  int64
#  26  strikes                          732071 non-null  int64
#  27  game_year                        732071 non-null  int64
#  28  pfx_x                            725431 non-null  float64
#  29  pfx_z                            725431 non-null  float64
#  30  plate_x                          725431 non-null  float64
#  31  plate_z                          725431 non-null  float64
#  32  on_3b                            67139 non-null   float64
#  33  on_2b                            133603 non-null  float64
#  34  on_1b                            221524 non-null  float64
#  35  outs_when_up                     732071 non-null  int64
#  36  inning                           732071 non-null  int64
#  37  inning_topbot                    732071 non-null  object
#  38  hc_x                             125238 non-null  float64
#  39  hc_y                             125238 non-null  float64
#  40  tfs_deprecated                   0 non-null       float64
#  41  tfs_zulu_deprecated              0 non-null       float64
#  42  fielder_2                        730947 non-null  float64
#  43  umpire                           0 non-null       float64
#  44  sv_id                            0 non-null       float64
#  45  vx0                              725431 non-null  float64
#  46  vy0                              725431 non-null  float64
#  47  vz0                              725431 non-null  float64
#  48  ax                               725431 non-null  float64
#  49  ay                               725431 non-null  float64
#  50  az                               725431 non-null  float64
#  51  sz_top                           725431 non-null  float64
#  52  sz_bot                           725431 non-null  float64
#  53  hit_distance_sc                  192031 non-null  float64
#  54  launch_speed                     200586 non-null  float64
#  55  launch_angle                     200587 non-null  float64
#  56  effective_speed                  727871 non-null  float64
#  57  release_spin_rate                712819 non-null  float64
#  58  release_extension                725431 non-null  float64
#  59  game_pk                          732071 non-null  int64
#  60  pitcher.1                        732071 non-null  int64
#  61  fielder_2.1                      730947 non-null  float64
#  62  fielder_3                        730947 non-null  float64
#  63  fielder_4                        730947 non-null  float64
#  64  fielder_5                        730947 non-null  float64
#  65  fielder_6                        730947 non-null  float64
#  66  fielder_7                        730947 non-null  float64
#  67  fielder_8                        730947 non-null  float64
#  68  fielder_9                        730947 non-null  float64
#  69  release_pos_y                    725431 non-null  float64
#  70  estimated_ba_using_speedangle    123374 non-null  float64
#  71  estimated_woba_using_speedangle  123374 non-null  float64
#  72  woba_value                       185858 non-null  float64
#  73  woba_denom                       185858 non-null  float64
#  74  babip_value                      185858 non-null  float64
#  75  iso_value                        185858 non-null  float64
#  76  launch_speed_angle               123374 non-null  float64
#  77  at_bat_number                    732071 non-null  int64
#  78  pitch_number                     732071 non-null  int64
#  79  pitch_name                       726981 non-null  object
#  80  home_score                       732071 non-null  int64
#  81  away_score                       732071 non-null  int64
#  82  bat_score                        732071 non-null  int64
#  83  fld_score                        732071 non-null  int64
#  84  post_away_score                  732071 non-null  int64
#  85  post_home_score                  732071 non-null  int64
#  86  post_bat_score                   732071 non-null  int64
#  87  post_fld_score                   732071 non-null  int64
#  88  if_fielding_alignment            727344 non-null  object
#  89  of_fielding_alignment            727344 non-null  object
#  90  spin_axis                        725431 non-null  float64
#  91  delta_home_win_exp               732069 non-null  float64
#  92  delta_run_exp                    732002 non-null  float64
#  93  year                             732071 non-null  int64
# dtypes: float64(56), int64(21), object(17)
# memory usage: 525.0+ MB

# %% [markdown]
# This data can be cleaned a bit before importing to improve performance. Drop all deprecated features to start.

# %%
statcast_2019.to_sql('statcast_2019', engine, if_exists='replace', chunksize= 50, method='multi')

# %%
pybaseball.cache.enable()
statcast_2018 = statcast('2018-03-31', '2018-11-30')
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/212 [00:00<?, ?it/s]
# Skipping offseason dates
# 100%|██████████| 212/212 [06:06<00:00,  1.73s/it]

# %%
statcast_2018.to_sql('statcast_2018', engine, if_exists='replace', chunksize= 50, method='multi')

# %%
pybaseball.cache.enable()
statcast_2017 = statcast('2017-03-31', '2017-11-30')
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/214 [00:00<?, ?it/s]
# Skipping offseason dates
# Skipping offseason dates
# 100%|██████████| 214/214 [05:46<00:00,  1.62s/it]

# %%
statcast_2017.to_sql('statcast_2017', engine, if_exists='replace', chunksize= 100, method='multi')

# %%
pybaseball.cache.enable()
statcast_2016 = statcast('2016-03-31', '2016-11-30')
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/214 [00:00<?, ?it/s]
# Skipping offseason dates
# Skipping offseason dates
# 100%|██████████| 214/214 [05:41<00:00,  1.60s/it]

# %%
statcast_2016.to_sql('statcast_2016', engine, if_exists='replace', chunksize= 100, method='multi')

# %%
pybaseball.cache.enable()
statcast_2020 = statcast('2020-03-31', '2020-11-30')
statcast_2020['season'] = 2020
# Out:
# This is a large query, it may take a moment to complete
#   0%|          | 0/97 [00:00<?, ?it/s]
# Skipping offseason dates
# Skipping offseason dates
# 100%|██████████| 97/97 [02:17<00:00,  1.41s/it]

# %%
statcast_2020.to_sql('statcast_2020', engine, if_exists='replace', chunksize= 100, method='multi')

# %%
str(date.today())
# Out:
# '2021-08-09'

# %%
opening_day = '{}-03-31'.format(current_year)
opening_day
# Out:
# '2021-03-31'

# %%
# this will scrape statcast data dynamically with dates automatically set

today = str(date.today())
opening_day = '{}-03-31'.format(current_year)
opening_day
statcast_2021 = statcast(opening_day, today)
statcast_2021.head()
# Out:
# This is a large query, it may take a moment to complete
# 100%|██████████| 168/168 [00:31<00:00,  5.37it/s]
#      pitch_type  game_date  release_speed  release_pos_x  release_pos_z  \
# 1964         SI 2021-09-13           90.4          -2.44           4.25
# 2062         CU 2021-09-13           77.2          -2.49           4.15
# 2127         CU 2021-09-13           78.2          -2.31            4.3
# 2162         CU 2021-09-13           77.2          -2.53           4.24
# 2258         SI 2021-09-13           89.1           -2.2           4.46
#
#            player_name  batter  pitcher     events    description  ...  \
# 1964  Garza Jr., Ralph  596142   621248     single  hit_into_play  ...
# 2062  Garza Jr., Ralph  596142   621248       None  called_strike  ...
# 2127  Garza Jr., Ralph  596142   621248       None           ball  ...
# 2162  Garza Jr., Ralph  570482   621248  strikeout      foul_bunt  ...
# 2258  Garza Jr., Ralph  570482   621248       None  called_strike  ...
#
#       fld_score  post_away_score  post_home_score  post_bat_score  \
# 1964          5                5                6               6
# 2062          5                5                5               5
# 2127          5                5                5               5
# 2162          5                5                5               5
# 2258          5                5                5               5
#
#       post_fld_score if_fielding_alignment of_fielding_alignment spin_axis  \
# 1964               5         Infield shift              Standard       250
# 2062               5         Infield shift              Standard        81
# 2127               5         Infield shift              Standard        83
# 2162               5              Standard              Standard        81
# 2258               5             Strategic              Standard       254
#
#      delta_home_win_exp delta_run_exp
# 1964              0.301         0.668
# 2062                0.0         -0.04
# 2127                0.0         0.028
# 2162             -0.108        -0.322
# 2258                0.0         -0.08
#
# [5 rows x 92 columns]

# %%
# this works, but very slow, takes about 30 minutes - can probably cut down on the columns
# when finalizing, could parquet files be utilized?
# for advanced hitting stats, append the data (determine frequency, weekly?)
# for statcast, just replace

statcast_2021.to_sql('statcast_2021', engine, if_exists='replace', chunksize=200, method='multi')

# %%
from pybaseball import chadwick_register

# get the playerid data
# this should be a one time upload to the database per season(?) - these shouldn't change often
# perhaps a monthly cadence would work well with this table?

data = chadwick_register()

# %%
data
# Out:
#       name_last name_first  key_mlbam key_retro  key_bbref  key_fangraphs  \
# 0       Aardsma      David     430911  aardd001  aardsda01           1902
# 1         Aaron       Hank     110001  aaroh101  aaronha01        1000001
# 2         Aaron     Tommie     110002  aarot101  aaronto01        1000002
# 3          Aase        Don     110003  aased001   aasedo01        1000003
# 4          Abad       Andy     407577  abada001   abadan01            506
# ...         ...        ...        ...       ...        ...            ...
# 24083      Zupo      Frank     124788  zupof101   zupofr01        1014464
# 24084   Zuvella       Paul     124789  zuvep001  zuvelpa01        1014465
# 24085  Zuverink     George     124790  zuveg101  zuverge01        1014466
# 24086  Zwilling      Dutch     124791  zwild101  zwilldu01        1014467
# 24087      Zych       Tony     543964  zycht001   zychto01          12876
#
#        mlb_played_first  mlb_played_last
# 0                2004.0           2015.0
# 1                1954.0           1976.0
# 2                1962.0           1971.0
# 3                1977.0           1990.0
# 4                2001.0           2006.0
# ...                 ...              ...
# 24083            1957.0           1961.0
# 24084            1982.0           1991.0
# 24085            1951.0           1959.0
# 24086            1910.0           1916.0
# 24087            2015.0           2017.0
#
# [24088 rows x 8 columns]

# %%
data.to_sql('player_lookup', engine, if_exists='replace')

# %%
# get advanced hitting data into the database - that one will take some cleaning/filtering
# once tested and validated, create the script

from pybaseball import batting_stats, pitching_stats

# hitting = pybaseball.batting_stats(2018, 2021)
# this code works, for whatever reason pybaseball is mixed up, but
# below code has been confirmed

hitting = batting_stats(current_year, current_year, qual=1)

# note that there is a bug in the pybaseball code that is causing the fangraph pitcher data to be missing
# may have to edit the pybaseball code to fix the issue
# https://github.com/jldbc/pybaseball/issues/221

# pitching = pitching_stats(2021)

# %%
# for advanced stats, having a pull date would be useful
# this way we can capture snapshots of performance through time

hitting['date_pull'] = date.today()

# %%
# remove special characters from column names for postgresql requirements

hitting.columns = hitting.columns.str.replace('%', 'pct')
hitting.columns = hitting.columns.str.replace(r'[()]', '', regex=True)

# %%
hitting
# Out:
#       IDfg  Season                   Name   Team  Age    G   AB   PA    H  1B  \
# 30   19611    2021  Vladimir Guerrero Jr.    TOR   22  115  422  494  133  77
# 50   17929    2021      Cedric Mullins II    BAL   26  112  432  483  139  86
# 99   12533    2021          Marcus Semien    TOR   30  116  462  514  126  65
# 33   19755    2021          Shohei Ohtani    LAA   26  115  394  453  106  37
# 60   17350    2021          Rafael Devers    BOS   24  113  422  478  120  59
# ..     ...     ...                    ...    ...  ...  ...  ...  ...  ...  ..
# 393  15983    2021          Clint Frazier    NYY   26   66  183  218   34  20
# 637  24655    2021            Owen Miller    CLE   24   31   92  100   13   9
# 619  14818    2021           JaCoby Jones    DET   29   36  100  105   17  13
# 559  17468    2021       Kelvin Gutierrez  - - -   26   46  158  168   33  26
# 642  19858    2021           Luis Rengifo    LAA   24   28   86   91   13  10
#
#      ...  maxEV  HardHit  HardHitpct  Events  CStrpct  CSWpct    xBA   xSLG  \
# 30   ...  117.4      187       0.552     339    0.131   0.256  0.305  0.594
# 50   ...  109.3      141       0.405     348    0.174   0.248  0.285  0.457
# 99   ...  109.5      147       0.421     349    0.164   0.256  0.238  0.431
# 33   ...  119.0      144       0.560     257    0.145   0.298  0.282  0.657
# 60   ...  114.4      165       0.516     320    0.099   0.244  0.281  0.562
# ..   ...    ...      ...         ...     ...      ...     ...    ...    ...
# 393  ...  111.5       49       0.415     118    0.190   0.294  0.205  0.346
# 637  ...  107.4       17       0.293      58    0.183   0.303  0.181  0.259
# 619  ...  107.3       21       0.362      58    0.172   0.348  0.200  0.349
# 559  ...  111.9       52       0.441     118    0.210   0.334  0.213  0.295
# 642  ...  108.9       16       0.239      67    0.165   0.291  0.199  0.336
#
#      xwOBA   date_pull
# 30   0.420  2021-08-15
# 50   0.357  2021-08-15
# 99   0.323  2021-08-15
# 33   0.428  2021-08-15
# 60   0.390  2021-08-15
# ..     ...         ...
# 393  0.311  2021-08-15
# 637  0.227  2021-08-15
# 619  0.255  2021-08-15
# 559  0.250  2021-08-15
# 642  0.251  2021-08-15
#
# [958 rows x 320 columns]

# %%
# note that % symbols need to be removed from column headers for postgresql import
# add a date column with today's date if hitting stats will be scraped daily/weekly

from sqlalchemy import create_engine

hitting.to_sql('hitting', engine, if_exists='append', chunksize= 100, method='multi')

# %%
from pybaseball import pitching_stats

pitching = pitching_stats(2021, qual=1)
pitching
# Out:
#       IDfg  Season              Name   Team  Age   W   L  WAR   ERA   G  ...  \
# 89   19361    2021     Corbin Burnes    MIL   26   7   4  5.6  2.23  20  ...
# 126  10310    2021      Zack Wheeler    PHI   31  10   7  5.5  2.56  24  ...
# 51   10954    2021      Jacob deGrom    NYM   33   7   2  4.9  1.08  15  ...
# 335   9132    2021    Nathan Eovaldi    BOS   31  10   7  4.1  3.92  23  ...
# 106  16137    2021      Carlos Rodon    CHW   28   9   5  4.1  2.38  19  ...
# ..     ...     ...               ...    ...  ...  ..  ..  ...   ...  ..  ...
# 675  16130    2021        David Hess    MIA   27   2   2 -0.8  8.00  14  ...
# 724  15068    2021     Yency Almonte    COL   27   1   2 -0.8  9.58  34  ...
# 544   4696    2021        Nate Jones  - - -   35   0   2 -0.9  5.68  20  ...
# 542  10811    2021  Mike Foltynewicz    TEX   29   2  11 -1.0  5.66  23  ...
# 629  15846    2021       Adam Plutko    BAL   29   1   2 -1.3  6.71  38  ...
#
#        LA  Barrels  Barrel%  maxEV  HardHit  HardHit%  Events  CStr%   CSW%  \
# 89    7.6        7    0.025  114.2       79     0.284     278  0.181  0.346
# 126   8.4       20    0.049  118.6      124     0.302     411  0.157  0.282
# 51   13.7       11    0.066  112.0       61     0.367     166  0.142  0.358
# 335  12.7       23    0.059  115.6      135     0.345     391  0.173  0.296
# 106  17.5       16    0.065  114.6       93     0.380     245  0.149  0.304
# ..    ...      ...      ...    ...      ...       ...     ...    ...    ...
# 675  21.8        8    0.133  116.5       30     0.500      60  0.131  0.217
# 724  13.7        8    0.084  110.2       30     0.316      95  0.152  0.257
# 544  18.4        7    0.117  112.8       27     0.450      60  0.107  0.239
# 542  16.8       39    0.097  116.5      179     0.444     403  0.169  0.247
# 629  23.2       21    0.116  113.1       72     0.398     181  0.114  0.217
#
#      xERA
# 89   1.76
# 126  2.72
# 51   1.54
# 335  3.39
# 106  2.53
# ..    ...
# 675  6.20
# 724  5.66
# 544  6.04
# 542  5.41
# 629  6.52
#
# [793 rows x 334 columns]

# %%
pitching['date_pull'] = date.today()

# %%
# remove special characters from column names for postgresql requirements

pitching.columns = pitching.columns.str.replace('%', 'pct')
pitching.columns = pitching.columns.str.replace(r'[()]', '', regex=True)

# %%
pitching.to_sql('pitching', engine, if_exists='append', chunksize= 100, method='multi')

# %%
pitching.loc[pitching['Name']=='Craig Kimbrel']
# Out:
#     IDfg  Season           Name   Team  Age  W  L  WAR   ERA   G  ...  \
# 54  6655    2021  Craig Kimbrel  - - -   33  2  3  2.1  1.25  46  ...
#
#     Barrels  Barrelpct  maxEV  HardHit  HardHitpct  Events  CStrpct  CSWpct  \
# 54        5      0.064  114.3       28       0.359      78    0.179   0.364
#
#     xERA   date_pull
# 54  1.95  2021-08-15
#
# [1 rows x 335 columns]
